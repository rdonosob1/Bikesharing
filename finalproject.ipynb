# %% [markdown]
# <a href="https://colab.research.google.com/github/rdonosob1/Bikesharing/blob/main/finalproject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import files
upload=files.upload()
# Out:
#      <input type="file" id="files-08105e1f-ded6-4111-a280-18ea1dd121ca" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-08105e1f-ded6-4111-a280-18ea1dd121ca">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
ventas_linea_df = pd.read_csv('ventas_linea (1).csv')

# %%
ventas_linea_df. head(50)
# Out:
# Empty DataFrame
# Columns: [id, order_id, product_id, product_uom_qty, create_uid, price_unit, price_subtotal]
# Index: []

# %%
print(ventas_linea_df.columns)
# Out:
# Index(['id', 'order_id', 'product_id', 'product_uom_qty', 'create_uid',
#        'price_unit', 'price_subtotal'],
#       dtype='object')

# %%
new_ventas_linea_df= ventas_linea_df['create_uid'].str.startswith('SUC')
ventas_linea_df= ventas_linea_df.loc[new_ventas_linea_df,['id',	'order_id',	'product_id',	'product_uom_qty',	'create_uid',	'price_unit',	'price_subtotal']]
ventas_linea_df.head()
# Out:
# Empty DataFrame
# Columns: [id, order_id, product_id, product_uom_qty, create_uid, price_unit, price_subtotal]
# Index: []

# %%
# Find null values and sum all null values
ventas_linea_df = ventas_linea_df.drop(ventas_linea_df[ventas_linea_df == "false"].index)
print(ventas_linea_df)
# Out:
# Empty DataFrame
# Columns: [id, order_id, product_id, product_uom_qty, create_uid, price_unit, price_subtotal]
# Index: []
